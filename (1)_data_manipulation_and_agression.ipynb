# %% [markdown]
# <a href="https://colab.research.google.com/github/mahinkhan1408/NID-Data-extraction-project/blob/main/(1)_data_manipulation_and_agression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/sample_data/california_housing_train.csv')
print(df)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
af = pd.read_csv('/content/UCL_AllTime_Performance_Table - UCL_Alltime_Performance_Table.csv')
print(af)
# Out:
#          #               Team   M.    W   D    L       goals  Dif  Pt.
# 0      1.0        Real Madrid  486  291  85  110  1076:55:00  533  533
# 1      2.0     Bayern München  388  231  78   79   817:24:00  427  427
# 2      3.0       FC Barcelona  341  196  77   68   675:51:00  319  319
# 3      4.0  Manchester United  289  153  69   67   524:56:00  224  224
# 4      5.0           Juventus  297  151  68   78   472:57:00  171  171
# ..     ...                ...  ...  ...  ..  ...         ...  ...  ...
# 349  350.0       KR Reykjavík    6    0   0    6        7:35  -28  -28
# 350  351.0        Keflavík ÍF    8    0   0    8        5:35  -30  -30
# 351  352.0    Stade Dudelange    4    0   0    4        1:32  -31  -31
# 352  353.0   Union Luxembourg    8    0   0    8        2:39  -37  -37
# 353  354.0      Avenir Beggen    8    0   0    8        0:44  -44  -44
#
# [354 rows x 9 columns]

# %%
af.aggregate(['sum', 'min'])
# Out:
#            #                                               Team     M.     W  \
# sum  56866.0  Real MadridBayern MünchenFC BarcelonaMancheste...  11772  4616
# min      1.0                             1. FC Frankfurt (Oder)      2     0
#
#         D     L                                              goals  Dif  Pt.
# sum  2538  4616  1076:55:00817:24:00675:51:00524:56:00472:57:00...    0    0
# min     0     0                                                0:1  -97  -97

# %%
re = pd.read_csv('/content/RealEstateUnitedStates.csv')
print(re)
# Out:
#       Year     Month         Region Home Size  Average Sales Price  \
# 0     2022  December        Midwest    Double             144300.0
# 1     2022  December        Midwest   Single               82300.0
# 2     2022  December        Midwest    Total1             104700.0
# 3     2022  December      Northeast    Double             158300.0
# 4     2022  December      Northeast   Single               75300.0
# ...    ...       ...            ...       ...                  ...
# 1570  2014   January  United States   Single               48000.0
# 1571  2014   January  United States    Total1              68300.0
# 1572  2014   January           West    Double              93900.0
# 1573  2014   January           West   Single               55400.0
# 1574  2014   January           West    Total1              87700.0
#
#       Number of Households (Thousands)  Median Income - Current Dollars  \
# 0                              28280.0                          73070.0
# ...

# %%
#lets find out the avergae sales price in united states region

avgprice= re.groupby('Region')['Average Sales Price'].mean()

print(avgprice)


avghome= re.groupby('Home Size')['Average Sales Price'].mean()
print(avghome)
# Out:
# Region
# Midwest          77933.333333
# Northeast        83359.365079
# South            80594.603175
# United States    82175.873016
# West             93298.412698
# Name: Average Sales Price, dtype: float64
# Home Size
# Double     107073.904762
# Single      57197.523810
# Total1      86145.523810
# Name: Average Sales Price, dtype: float64

# %%
goalavg = af.groupby('Team')['M.'].mean()
print(goalavg.to_string())
# Out:
# Team
# 1. FC Frankfurt (Oder)             21.0
# 1. FC Kaiserslautern               12.0
# 1. FC Köln                         17.0
# 1. FC Magdeburg                     8.0
# 1. FC Nürnberg                      8.0
# 1. FC Saarbrücken                   2.0
# 1. FC Union Berlin                  6.0
# 1899 Hoffenheim                     6.0
# AB Gladsaxe                         4.0
# AC Milan                          265.0
# AC Sparta Praha                   102.0
# ACF Fiorentina                     39.0
# AE Lárissa                          2.0
# AEK Athen                          56.0
# AEL Limassol                        2.0
# AFC Ajax                          215.0
# AFC DWS                             6.0
# AIK Solna                           8.0
# AJ Auxerre                         20.0
# APOEL Nikosia                      40.0
# AS Monaco                          98.0
# AS Roma                           109.0
# AS Saint-Étienne                   39.0
# ...

# %%
esus = pd.read_csv('/content/excel_export (1).csv')

print(esus)
# Out:
#         Status                WO #      Work Type  Client State  Date Due  \
# 0    Cancelled          1061203253   Snow Removal    9102    IL  02-06-25
# 1    Cancelled          1061201299   Snow Removal    9102    IL  01-31-25
# 2    Cancelled          1061199149   Snow Removal    9102    IL  01-22-25
# 3    Cancelled          1061197921   Snow Removal    9102    WI  01-17-25
# 4       Closed          1061196387   Snow Removal    9102    IL  01-11-25
# ..         ...                 ...            ...     ...   ...       ...
# 495     Closed  101992- Electrical  Turn Estimate    2115    IN  05-15-24
# 496     Closed      101992- Stairs  Turn Estimate    2115    IN  05-15-24
# 497     Closed         00579946-BA    OM Approval    9111    AL  05-15-24
# 498  Cancelled              215017    OM Estimate    6609    PA  05-15-24
# 499     Closed     453149587-IS-Z1      Misc.Work    9106    MS  05-15-24
#
#     Ready Office Date Received         Category Customer        Loan #  \
# ...

# %% [markdown]
# **Aggregate**
#
# * aggregation dataset
# * sum,max,min

# %%
esus.aggregate(['sum', 'min'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-4744b2d3d18a> in <cell line: 1>()
# ----> 1 esus.aggregate({'Column1': 'sum', 'Column2': 'min'})
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in aggregate(self, func, axis, *args, **kwargs)
#    9194
#    9195         op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# -> 9196         result = op.agg()
#    9197
#    9198         if relabeling:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in agg(self)
#     688         result = None
#     689         try:
# --> 690             result = super().agg()
#     691         finally:
#     692             self.obj = obj
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in agg(self)
#     161
#     162         if is_dict_like(arg):
# --> 163             return self.agg_dict_like()
# ...
